# %%
import pandas as pd
import numpy as np
df = pd.read_csv('titanic-passengers.csv',sep=";")
df.info()
df.describe()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# ...

# %%
#2.	As a next step apply what you have learned in Data preprocessing to preprocess your data: 
#find missing informations and replace them by the appropriate values.

# %%
df['Age'].fillna(df['Age'].mean(0),inplace=True)
df['Embarked'].fillna('S',inplace=True)
df['Cabin'].fillna('G6',inplace=True)
df['Age']= df['Age'].astype(float).astype(int)
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex  Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male   28      0
# 1                              Moen, Mr. Sigurd Hansen    male   25      0
# 2                               Jensen, Mr. Hans Peder    male   20      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female   29      0
# 4                               Davidson, Mr. Thornton    male   31      1
# ..                                                 ...     ...  ...    ...
# ...

# %%
#Transform categorical data using method of your choice(labelEncoder)

# %%
df2 = df
#from sklearn.preprocessing import LabelEncoder
#encoder=LabelEncoder()
#df2['Survived'] =encoder.fit_transform(df2['Survived'])
#df2['Sex'] =encoder.fit_transform(df2['Sex'])
#df2['Ticket'] =encoder.fit_transform(df2['Ticket'])
#df2['Cabin'] =encoder.fit_transform(df2['Cabin'])
#df2['Embarked'] =encoder.fit_transform(df2['Embarked'])
df2
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex  Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male   28      0
# 1                              Moen, Mr. Sigurd Hansen    male   25      0
# 2                               Jensen, Mr. Hans Peder    male   20      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female   29      0
# 4                               Davidson, Mr. Thornton    male   31      1
# ..                                                 ...     ...  ...    ...
# ...

# %%
df2.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    int32
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(1), int32(1), int64(4), object(6)
# memory usage: 80.2+ KB
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# ...

# %%
#Transform categorical data using method of your choicone hot encoding

# %%
one_hot = pd.get_dummies(df2['Sex'])
df2 = df2.drop('Sex',axis = 1)
df2 = df2.join(one_hot)
one_hot = pd.get_dummies(df2['Survived'])
df2 = df2.drop('Survived',axis = 1)
df2 = df2.join(one_hot)
df2
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            343       2                         Collander, Mr. Erik Gustaf
# 1             76       3                            Moen, Mr. Sigurd Hansen
# 2            641       3                             Jensen, Mr. Hans Peder
# 3            568       3        Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4            672       1                             Davidson, Mr. Thornton
# ..           ...     ...                                                ...
# 886           10       2                Nasser, Mrs. Nicholas (Adele Achem)
# 887           61       3                              Sirayanian, Mr. Orsen
# 888          535       3                                Cacic, Miss. Marija
# 889          102       3                   Petroff, Mr. Pastcho ("Pentcho")
# 890          428       2  Phillips, Miss. Kate Florence ("Mrs Kate Louis...
#
# ...

# %%
df2.info()
df2.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Pclass       891 non-null    int64
#  2   Name         891 non-null    object
#  3   Age          891 non-null    int32
#  4   SibSp        891 non-null    int64
#  5   Parch        891 non-null    int64
#  6   Ticket       891 non-null    object
#  7   Fare         891 non-null    float64
#  8   Cabin        891 non-null    object
#  9   Embarked     891 non-null    object
#  10  female       891 non-null    uint8
#  11  male         891 non-null    uint8
#  12  No           891 non-null    uint8
#  13  Yes          891 non-null    uint8
# dtypes: float64(1), int32(1), int64(4), object(4), uint8(4)
# memory usage: 69.7+ KB
#        PassengerId      Pclass         Age       SibSp       Parch  \
# ...
